# %% [markdown]
# ### Analyzing the World Bank's Twitter Feed, Judy Yang, DAT10 Project
# ### Part 3. Data Exploration

# %%
pwd
# Out:
# u'/Users/judyyang/Documents/GA_DS_course/Final_Project/notebooks'

# %%
from datetime import datetime
import time
import json
import operator 
import preprocess
from collections import Counter
#from textblob import TextBlob

import pandas as pd
from pandas import ExcelWriter
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
#% sign 

import numpy as np
import scipy as sp
from sklearn.cross_validation import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from textblob import TextBlob, Word
from nltk.stem.snowball import SnowballStemmer

from ttp import ttp

pd.options.display.max_columns = 50
pd.options.display.max_rows= 50
pd.options.display.width= 120

# %%
# Create excel to save outputs from this notebook
writer = ExcelWriter('./data/Project03_outputs.xlsx')

# %%
wb = pd.read_pickle('./data/WorldBank_all_processed_17feb_2016')
wb.shape
# Out:
# (93733, 20)

# %%
wb.user_screen_name.value_counts()
# Out:
# WBG_Agriculture    3200
# worldbankdata      3200
# WorldBankPSD       3200
# WorldBankSAsia     3200
# WBG_Cities         3200
# WBG_Finance        3200
# wbg_gov            3200
# WBG_Environment    3200
# WBG_Gender         3200
# WorldBank_IEG      3200
# WBG_Education      3200
# WorldBankWater     3200
# WBPubs             3200
# WBG_Poverty        3200
# WBG_Climate        3200
# WBG_LeadINLearn    3200
# IFC_org            3200
# WorldBankAfrica    3200
# WorldBankSEI       3200
# WBG_Health         3200
# wb_research        3199
# WorldBank          3196
# WBG_PPP            2961
# WorldBankVideos    2725
# MIGAWorldBank      2000
# WorldBankIndia     1907
# WBG_SPLabor        1810
# WorldBankKenya     1707
# WBG_Energy         1695
# WBCaribbean        1597
# WBG_Transport      1508
# WorldBankPhotos    1259
# WBOpenFinances     1123
# WorldBankECA        808
# impacteval          745
# WBG_Dev4Peace       649
# WBedutech           508
# JimKim_WBG          336
# Name: user_screen_name, dtype: int64

# %%
wb.groupby('user_screen_name').is_RT.mean()
# Out:
# user_screen_name
# IFC_org            0.195312
# JimKim_WBG         0.059524
# MIGAWorldBank      0.477500
# WBCaribbean        0.233563
# WBG_Agriculture    0.062187
# WBG_Cities         0.143437
# WBG_Climate        0.133750
# WBG_Dev4Peace      0.302003
# WBG_Education      0.333125
# WBG_Energy         0.323894
# WBG_Environment    0.255312
# WBG_Finance        0.217812
# WBG_Gender         0.285313
# WBG_Health         0.294375
# WBG_LeadINLearn    0.103750
# WBG_PPP            0.343465
# WBG_Poverty        0.133750
# WBG_SPLabor        0.213812
# WBG_Transport      0.233422
# WBOpenFinances     0.178985
# WBPubs             0.271250
# WBedutech          0.094488
# WorldBank          0.114518
# WorldBankAfrica    0.315937
# WorldBankECA       0.240099
# WorldBankIndia     0.104877
# WorldBankKenya     0.462214
# WorldBankPSD       0.222812
# WorldBankPhotos    0.418586
# WorldBankSAsia     0.125625
# WorldBankSEI       0.142813
# WorldBankVideos    0.486239
# WorldBankWater     0.383125
# WorldBank_IEG      0.283438
# impacteval         0.210738
# wb_research        0.107846
# wbg_gov            0.218750
# worldbankdata      0.392188
# Name: is_RT, dtype: float64

# %%
#Create data set of just own tweets because stats are based on original tweet
wb = wb[(wb.is_RT==0)]
wb.shape
# Out:
# (71287, 20)

# %%
sns.set(style="darkgrid", color_codes=True)
sns.set_context("paper")
plt.figure(figsize=(16, 8))
sns.stripplot(x="year_cat",y="retweet_count",data=wb, hue="user_screen_name", jitter=True)
sns.plt.title("World Bank Related Accounts Retweet Counts")
plt.show()

# %%
#Examine just the Poverty GP
#wb=wb[wb.user_screen_name=="WBG_Poverty"]
wb=wb[wb.user_screen_name=="WorldBank"]

# %%
sns.set(style="darkgrid", color_codes=True)
sns.set_context("paper")
plt.figure(figsize=(16, 8))
sns.stripplot(x="year_cat",y="retweet_count",data=wb,  jitter=True)
sns.plt.title("World Bank Account Retweet Counts")
plt.show()

# %%
#always reset index
wb = wb.reset_index()

# %%
wb.columns
# Out:
# Index([           u'index',               u'id', u'user_screen_name',       u'created_at',   u'favorite_count',
#           u'retweet_count',             u'text',           u'length',            u'is_RT',           u'has_ht',
#                u'has_link',           u'has_at',             u'tags',            u'users',       u'text_clean',
#             u'has_retweet',     u'has_favorite',             u'year',         u'year_cat',       u'year_month',
#            u'fav_RT_ratio'],
#       dtype='object')

# %%
wb.user_screen_name.value_counts()
# Out:
# WorldBank    2830
# Name: user_screen_name, dtype: int64

# %% [markdown]
# **----------------------------------------------------------------------------------------------------------**
# ### Examine the data set
#
# Look for trends
# Examine favorite and retweet count trends

# %%
wb.describe()
# Out:
#               index            id  favorite_count  retweet_count       length  is_RT    has_ht  has_link    has_at  \
# count   2830.000000  2.830000e+03     2830.000000    2830.000000  2830.000000   2830      2830      2830      2830
# mean   31752.174205  6.637333e+17       41.320495      58.586926   131.725088      0  0.866431  0.983392  0.286572
# std     1022.936782  1.833624e+16       35.768710      48.550601    10.905587      0  0.340249  0.127819   0.45224
# min    29963.000000  6.337479e+17        0.000000       0.000000    33.000000  False     False     False     False
# 25%    30857.500000  6.488499e+17       24.000000      32.000000   127.000000      0         1         1         0
# 50%    31773.500000  6.596497e+17       34.000000      47.000000   135.000000      0         1         1         0
# 75%    32629.750000  6.797544e+17       49.000000      70.000000   139.000000      0         1         1         1
# max    33513.000000  6.990669e+17      910.000000    1087.000000   148.000000  False      True      True      True
#
#        has_retweet  has_favorite  fav_RT_ratio
# count  2830.000000   2830.000000   2828.000000
# mean      0.998233      0.998587           inf
# std       0.042003      0.037576           NaN
# min       0.000000      0.000000      0.000000
# 25%       1.000000      1.000000      0.583333
# 50%       1.000000      1.000000      0.721121
# 75%       1.000000      1.000000      0.904987
# max       1.000000      1.000000           inf

# %% [markdown]
# **Retweet observations**
#
# 1.Tweets regarding world events to be about world events, and all are retweets from other users. So analyze just own tweets.
#
# 2.Among own tweets, WDR has high retweet
#
# 2.endpoverty hashtags have high retwets

# %%
#How many tweets have 0 retweets
wb[(wb.retweet_count==0)].user_screen_name.value_counts()
# Out:
# WorldBank    4
# Name: user_screen_name, dtype: int64

# %%
wb.sort_values("retweet_count", ascending=False).head()
# Out:
#      index                  id user_screen_name          created_at  favorite_count  retweet_count  \
# 591  30716  682940695980699648        WorldBank 2016-01-01 15:05:25             378           1087
# 269  30311  691276856251846656        WorldBank 2016-01-24 15:10:20             910            896
# 374  30442  688346273276121088        WorldBank 2016-01-16 13:05:15             770            677
# 372  30440  688376535389212672        WorldBank 2016-01-16 15:05:30             246            439
# 650  30789  681445769166110722        WorldBank 2015-12-28 12:05:06             223            390
#
#                                                   text  length  is_RT has_ht has_link has_at              tags users  \
# 591  Where the extreme poor live\nIndia 33%  \nChin...     140  False  False     True  False
# 269  Where are the cheapest and most expensive coun...     131  False   True     True  False           WDR2016
# 374  #SriLanka is the cheapest place for mobile. Se...     124  False   True     True  False  SriLanka WDR2016
# 372  Only 15% of the world's population has high-sp...     132  False   True     True  False  digitaldividends
# 650  A 10% increase in the use of the internet in a...     140  False  False     True  False
#
#                                             text_clean  has_retweet  has_favorite year year_cat year_month  \
# 591  Where the extreme poor live India    China    ...            1             1   16       16      16-01
# 269  Where are the cheapest and most expensive coun...            1             1   16       16      16-01
# 374   SriLanka is the cheapest place for mobile  Se...            1             1   16       16      16-01
# 372  Only  of the worldpopulation has high speed in...            1             1   16       16      16-01
# 650  A  increase in the use of the internet incount...            1             1   15       15      15-12
#
#      fav_RT_ratio
# 591      0.347746
# 269      1.015625
# 374      1.137371
# 372      0.560364
# 650      0.571795

# %%
wb[(wb.retweet_count==0)]
# Out:
#       index                  id user_screen_name          created_at  favorite_count  retweet_count  \
# 162   30177  693963777771859968        WorldBank 2016-02-01 01:07:12               0              0
# 720   30877  679358384836100096        WorldBank 2015-12-22 17:50:35               1              0
# 1568  31960  656863394851631104        WorldBank 2015-10-21 16:03:31               2              0
# 2246  32785  647084433246437377        WorldBank 2015-09-24 16:25:25               0              0
#
#                                                    text  length  is_RT has_ht has_link has_at                  tags  \
# 162   @halabugaighis https://t.co/ZIIQ2WkxEq Not sur...     105  False  False     True   True
# 720   @HuffPostGreen: John Roome on @WorldBank’s tak...     126  False   True     True   True  ParisAgreement COP21
# 1568  @rkyte365 on why we need a strong climate deal...     127  False   True     True   True   COP21 PriceOnCarbon
# 2246  @bharat_sas Saswat, you can shoot a short vide...     130  False   True    False   True              youthbiz
#
#                         users                                         text_clean  has_retweet  has_favorite year  \
# 162             halabugaighis   halabugaighis   Not sure the status of an arc...            0             0   16
# 720   HuffPostGreen WorldBank   HuffPostGreen  John Roome on  WorldBanktake o...            0             0   15
# 1568                 rkyte365   rkyteon why we needstrong climate deal for  C...            0             1   15
# 2246               bharat_sas   bharat sas Saswat  you can shootshort video e...            0             0   15
#
#      year_cat year_month  fav_RT_ratio
# 162        16      16-02           NaN
# 720        15      15-12           inf
# 1568       15      15-10           inf
# 2246       15      15-09           NaN

# %%
#How many tweets have zero favorites
#almost all WB tweets are favorited at least once
wb[(wb.favorite_count==0)]
# Out:
#       index                  id user_screen_name          created_at  favorite_count  retweet_count  \
# 162   30177  693963777771859968        WorldBank 2016-02-01 01:07:12               0              0
# 1963  32445  651087096392892416        WorldBank 2015-10-05 17:30:35               0              2
# 2246  32785  647084433246437377        WorldBank 2015-09-24 16:25:25               0              0
#
#                                                    text  length  is_RT has_ht has_link has_at  \
# 162   @halabugaighis https://t.co/ZIIQ2WkxEq Not sur...     105  False  False     True   True
# 1963  @JimKim_WBG &amp; @Lagarde discuss #developmen...     137  False   True     True   True
# 2246  @bharat_sas Saswat, you can shoot a short vide...     130  False   True    False   True
#
#                                         tags               users                                         text_clean  \
# 162                                                halabugaighis   halabugaighis   Not sure the status of an arc...
# 1963  development civilsocietyorgs AMCSO2015  JimKim_WBG Lagarde   JimKim WBG     Lagarde discuss  development c...
# 2246                                youthbiz          bharat_sas   bharat sas Saswat  you can shootshort video e...
#
#       has_retweet  has_favorite year year_cat year_month  fav_RT_ratio
# 162             0             0   16       16      16-02           NaN
# 1963            1             0   15       15      15-10             0
# 2246            0             0   15       15      15-09           NaN

# %%
wb[wb.fav_RT_ratio>1]
# Out:
#       index                  id user_screen_name          created_at  favorite_count  retweet_count  \
# 5     29968  698916023727190016        WorldBank 2016-02-14 17:05:39              36             30
# 7     29971  698824320005570561        WorldBank 2016-02-14 11:01:16              49             48
# 12    29977  698583801623089152        WorldBank 2016-02-13 19:05:32              41             40
# 13    29978  698553568563961856        WorldBank 2016-02-13 17:05:23              33             28
# 27    29995  698100592749715456        WorldBank 2016-02-12 11:05:26              47             42
# 44    30016  697587155749752832        WorldBank 2016-02-11 01:05:13              66             64
# 47    30019  697497960637190144        WorldBank 2016-02-10 19:10:47              34             25
# 52    30029  697254950557061120        WorldBank 2016-02-10 03:05:09              33             31
# 59    30038  697035146701205505        WorldBank 2016-02-09 12:31:43              67             57
# 60    30040  696996551424614400        WorldBank 2016-02-09 09:58:22              41             33
# 66    30049  696741592749776896        WorldBank 2016-02-08 17:05:15              34             30
# 68    30054  696664197774622721        WorldBank 2016-02-08 11:57:42              30             22
# 75    30063  696557859333632000        WorldBank 2016-02-08 04:55:09              88             80
# 76    30065  696531475425005569        WorldBank 2016-02-08 03:10:19             187            134
# 97    30092  695775231898681344        WorldBank 2016-02-06 01:05:16              31             28
# 98    30093  695745089092632576        WorldBank 2016-02-05 23:05:30              37             35
# 101   30098  695657116317708288        WorldBank 2016-02-05 17:15:55              50             49
# 106   30105  695533642349682688        WorldBank 2016-02-05 09:05:17              48             35
# 108   30107  695485812197167109        WorldBank 2016-02-05 05:55:13             468            273
# 109   30108  695470702023954434        WorldBank 2016-02-05 04:55:11              37             32
# 111   30110  695427017420832768        WorldBank 2016-02-05 02:01:36              21             19
# 116   30117  695305961939058688        WorldBank 2016-02-04 18:00:34              21             20
# 117   30119  695261931163250688        WorldBank 2016-02-04 15:05:36              33             31
# 118   30120  695257146552946689        WorldBank 2016-02-04 14:46:35              36             28
# 119   30122  695200457308954624        WorldBank 2016-02-04 11:01:19              55             53
# ...     ...                 ...              ...                 ...             ...            ...
# 2330  32890  645539268014776320        WorldBank 2015-09-20 10:05:29              23             17
# 2335  32896  645434724832407552        WorldBank 2015-09-20 03:10:04              25             20
# 2337  32899  645327074253795333        WorldBank 2015-09-19 20:02:18              26             16
# 2351  32916  644964828029845505        WorldBank 2015-09-18 20:02:52              23             16
# 2356  32921  644874779372199937        WorldBank 2015-09-18 14:05:03              31             15
# 2363  32931  644723839692349441        WorldBank 2015-09-18 04:05:16              30             29
# 2367  32938  644648331503910916        WorldBank 2015-09-17 23:05:13              28             27
# 2376  32950  644481561035935744        WorldBank 2015-09-17 12:02:32              27             22
# 2377  32951  644467240864206848        WorldBank 2015-09-17 11:05:38              22             19
# 2384  32958  644346327715971073        WorldBank 2015-09-17 03:05:10              29             25
# 2392  32967  644225249828052992        WorldBank 2015-09-16 19:04:03              26             18
# 2401  32977  644075990982000640        WorldBank 2015-09-16 09:10:57              18             15
# 2413  32993  643848297107574786        WorldBank 2015-09-15 18:06:10              22             18
# 2440  33024  643439728344363008        WorldBank 2015-09-14 15:02:40              85             66
# 2444  33030  643365022433996800        WorldBank 2015-09-14 10:05:49              30             29
# 2634  33266  638653921947447298        WorldBank 2015-09-01 10:05:35              31             29
# 2716  33378  636499734803415040        WorldBank 2015-08-26 11:25:37              30             27
# 2717  33379  636489897851772928        WorldBank 2015-08-26 10:46:31              85             73
# 2723  33387  636372752623083520        WorldBank 2015-08-26 03:01:02             509            375
# 2728  33393  636225375866126336        WorldBank 2015-08-25 17:15:24             148            102
# 2750  33418  635645289047683073        WorldBank 2015-08-24 02:50:21              26             25
# 2791  33463  634578328037556224        WorldBank 2015-08-21 04:10:37              36             32
# 2817  33499  633957981042950144        WorldBank 2015-08-19 11:05:35              31             27
# 2821  33504  633897529772478464        WorldBank 2015-08-19 07:05:23              31             24
# 2825  33508  633839720049590272        WorldBank 2015-08-19 03:15:40              30             22
#
#                                                    text  length  is_RT has_ht has_link has_at  \
# 5     Do you have privacy laws in your country? How ...     142  False   True     True  False
# 7     We're accepting papers for our #ABCDE Conferen...     138  False   True     True  False
# 12    Women make up 2% of #mobilemoney users in Sout...     101  False   True     True  False
# 13    Come help #EndPoverty! Join us as a Web Conten...     132  False   True     True  False
# 27    With EDGE gender certification we're setting t...     140  False   True     True  False
# 44    This small #Indian village proves ending extre...     133  False   True     True  False
# 47    #Pakistan’s #financialinclusion goal: increase...     138  False   True     True  False
# 52    #Pakistan: Despite surge, &lt;5% of #women are...     143  False   True     True  False
# 59    Digital technology is transforming lives globa...     136  False   True     True  False
# 60    #Pakistan can attract more private sector inve...     140  False   True     True   True
# 66    Come work with us! We are looking for a Web Co...     138  False  False     True  False
# 68    .@JimKim_WBG begins a 2-day visit to #Pakistan...     135  False   True     True   True
# 75    A lesson from @MalalaFund, girl #education pay...     101  False   True     True   True
# 76    Why do you think there are so many #tech start...     133  False   True     True  False
# 97    This is how an online ticket machine is provid...     137  False   True     True  False
# 98    Ppl send out 803M tweets/day! How can we use t...     136  False   True     True  False
# 101   We must invest in young people’s #education &a...     144  False   True     True   True
# 106   This group in #NewZealand will inspire you to ...     128  False   True     True   True
# 108   Before mobile phones, how did you stay in touc...     139  False   True     True  False
# 109   An estimated 1M Syrians entered #Europe last y...     135  False   True     True   True
# 111   What keeps people where you live from using di...     131  False   True     True  False
# 116   Humanitarian crises often last years—a #refuge...     140  False   True     True   True
# 117   .@SupportSyrians aims to provide safer healthc...     143  False   True     True   True
# 118   "Our hearts are broken by the suffering of the...     138  False   True     True   True
# 119   The Internet can open opportunities. But not f...     138  False   True     True  False
# ...                                                 ...     ...    ...    ...      ...    ...
# 2330  .@DrewHolcomb &amp; his wife/bandmate @ellieho...     138  False   True     True   True
# 2335  .@IFC_org, @gs10kwomen welcome $100m pledge fr...     125  False  False     True   True
# 2337  What you need to know about #Health, in @World...     126  False   True     True   True
# 2351  How to advance #GlobalGoals on #oceans? These ...     136  False   True     True  False
# 2356  Cross-breeding &amp; testing finds 30 bean typ...     142  False   True     True   True
# 2363  W/ 150 shows/yr, the world is #Music4Dev 's @D...     138  False   True     True   True
# 2367  Engaging young development professionals on th...     123  False  False     True  False
# 2376  Cutting #carbon emissions is a choice. Watch w...     115  False   True     True  False
# 2377  .@worldbank is working w/ partners to make Uni...     136  False   True     True   True
# 2384  Zanzibar, #Tanzania works on curbing blast fis...     132  False   True     True  False
# 2392  Can #technology improve #roadsafety? Over 180 ...     131  False   True     True  False
# 2401  From #Africa to #Brazil: 3 takeaways on how to...     123  False   True     True  False
# 2413  Build your version of IFC Annual Report with r...     126  False   True     True  False
# 2440  Congrats @DjokerNole on winning  #USOpenFinal!...     140  False   True     True   True
# 2444  This innovative auction is designed to help su...     136  False   True     True  False
# 2634  Join our Google+ Hangout to find out the skill...     131  False   True     True  False
# 2716  Find out what's new on early childhood #educat...     134  False   True     True  False
# 2717  &lt;10% of #Serbia's poorest children attend p...     147  False   True     True   True
# 2723  150 million children under 5 don't have access...     134  False   True     True  False
# 2728  Watch @WorldBankLive tm for special event w/ @...     138  False   True     True   True
# 2750  .@MusicNegrito proves that your past doesn’t d...     122  False   True     True   True
# 2791  Did you know that the World Bank Group is now ...     138  False  False     True   True
# 2817  Blog: How do creditor rights matter for #debt ...     101  False   True     True  False
# 2821  #Tourism training is helping boost rural commu...     139  False   True     True   True
# 2825  Lessons from 3 companies preparing for a price...     104  False   True     True  False
#
#                                                 tags                                     users  \
# 5                                   digitaldividends
# 7                             ABCDE Data Development
# 12                                       mobilemoney
# 13                                        EndPoverty
# 27                                         diversity
# 44                                    Indian poverty
# 47    Pakistan financialinclusion SMEs finaccess2020
# 52      Pakistan women financialsector finaccess2020
# 59                                  digitaldividends
# 60                                          Pakistan                                JimKim_WBG
# 66
# 68                                          Pakistan                                JimKim_WBG
# 75                                         education                                MalalaFund
# 76                  tech California digitaldividends
# 97                                  employment Haiti
# 98                     transparency digitaldividends
# 101                                education refugee                                JimKim_WBG
# 106                                       NewZealand                           Connect4Climate
# 108                                 digitaldividends
# 109                            Europe SupportSyrians                                JimKim_WBG
# 111                                 digitaldividends
# 116                                          refugee                                JimKim_WBG
# 117                                            Syria                            SupportSyrians
# 118                                   SupportSyrians                                JimKim_WBG
# 119                                 digitaldividends
# ...                                              ...                                       ...
# 2330                                       Music4Dev                  DrewHolcomb ellieholcomb
# 2335                                                                IFC_org gs10kwomen OPICgov
# 2337                               Health MagsWeLove                                 WorldBank
# 2351                GlobalGoals oceans Tanzania SDGs
# 2356                                   climatechange                                     CGIAR
# 2363                               Music4Dev poverty                               DrewHolcomb
# 2367
# 2376                                          carbon
# 2377                                         Fin4Dev                                 worldbank
# 2384                                        Tanzania
# 2392                     technology roadsafety India
# 2401                         Africa Brazil education
# 2413                                   essential4dev
# 2440                                     USOpenFinal                                DjokerNole
# 2444                                         climate
# 2634                                jobs skills2jobs
# 2716                             education Flipboard
# 2717                               Serbia ServingECD                     JimKim_WBG DjokerNole
# 2723                                      ServingECD
# 2728                                      servingECD  WorldBankLive DjokerNole novakfoundation
# 2750                                       Music4dev                              MusicNegrito
# 2791                                                                                 Flipboard
# 2817                                    debt finance
# 2821                                         Tourism                               abrahampath
# 2825                                          carbon
#
#                                              text_clean  has_retweet  has_favorite year year_cat year_month  \
# 5     Do you have privacy laws in your country  How ...            1             1   16       16      16-02
# 7     We re accepting papers for our  ABCDE Conferen...            1             1   16       16      16-02
# 12    Women make up  of  mobilemoney users in South ...            1             1   16       16      16-02
# 13    Come help  EndPoverty  Join us asWeb Content P...            1             1   16       16      16-02
# 27    With EDGE gender certification we re setting t...            1             1   16       16      16-02
# 44    This small  Indian village proves ending extre...            1             1   16       16      16-02
# 47     Pakistan financialinclusion goal  increase ba...            1             1   16       16      16-02
# 52     Pakistan  Despite surge   lt  of  women are i...            1             1   16       16      16-02
# 59    Digital technology is transforming lives globa...            1             1   16       16      16-02
# 60     Pakistan can attract more private sector inve...            1             1   16       16      16-02
# 66    Come work with us  We are looking forWeb Conte...            1             1   16       16      16-02
# 68      JimKim WBG beginsday visit to  Pakistan to d...            1             1   16       16      16-02
# 75    A lesson from  MalalaFund  girl  education pay...            1             1   16       16      16-02
# 76    Why do you think there are so many  tech start...            1             1   16       16      16-02
# 97    This is how an online ticket machine is provid...            1             1   16       16      16-02
# 98    Ppl send out 803M tweets day  How can we use t...            1             1   16       16      16-02
# 101   We must invest in young people education    su...            1             1   16       16      16-02
# 106   This group in  NewZealand will inspire you to ...            1             1   16       16      16-02
# 108   Before mobile phones  how did you stay in touc...            1             1   16       16      16-02
# 109   An estimated 1M Syrians entered  Europe last y...            1             1   16       16      16-02
# 111   What keeps people where you live from using di...            1             1   16       16      16-02
# 116   Humanitarian crises often last years refugee c...            1             1   16       16      16-02
# 117     SupportSyrians aims to provide safer healthc...            1             1   16       16      16-02
# 118    Our hearts are broken by the suffering of the...            1             1   16       16      16-02
# 119   The Internet can open opportunities  But not f...            1             1   16       16      16-02
# ...                                                 ...          ...           ...  ...      ...        ...
# 2330    DrewHolcomb    his wife bandmate  ellieholco...            1             1   15       15      15-09
# 2335    IFC org   gs10kwomen welcome  100m pledge fr...            1             1   15       15      15-09
# 2337  What you need to know about  Health  in  World...            1             1   15       15      15-09
# 2351  How to advance  GlobalGoals on  oceans  These ...            1             1   15       15      15-09
# 2356  Cross breeding    testing finds bean types tha...            1             1   15       15      15-09
# 2363  W  shows yr  the world is  Music4Dev  DrewHolc...            1             1   15       15      15-09
# 2367  Engaging young development professionals on th...            1             1   15       15      15-09
# 2376  Cutting  carbon emissions ischoice  Watch what...            1             1   15       15      15-09
# 2377    worldbank is working partners to make Univer...            1             1   15       15      15-09
# 2384  Zanzibar   Tanzania works on curbing blast fis...            1             1   15       15      15-09
# 2392  Can  technology improve  roadsafety  Over deve...            1             1   15       15      15-09
# 2401  From  Africa to  Brazil  takeaways on how to i...            1             1   15       15      15-09
# 2413  Build your version of IFC Annual Report with r...            1             1   15       15      15-09
# 2440  Congrats  DjokerNole on winning   USOpenFinal ...            1             1   15       15      15-09
# 2444  This innovative auction is designed to help su...            1             1   15       15      15-09
# 2634  Join our Google  Hangout to find out the skill...            1             1   15       15      15-09
# 2716  Find out whatnew on early childhood  education...            1             1   15       15      15-08
# 2717   lt  of  Serbiapoorest children attend prescho...            1             1   15       15      15-08
# 2723  million children under donhave access to early...            1             1   15       15      15-08
# 2728  Watch  WorldBankLive tm for special event  Djo...            1             1   15       15      15-08
# 2750    MusicNegrito proves that your past doesndete...            1             1   15       15      15-08
# 2791  Did you know that the World Bank Group is now ...            1             1   15       15      15-08
# 2817  Blog  How do creditor rights matter for  debt ...            1             1   15       15      15-08
# 2821   Tourism training is helping boost rural commu...            1             1   15       15      15-08
# 2825  Lessons from companies preparing forprice on  ...            1             1   15       15      15-08
#
#       fav_RT_ratio
# 5         1.200000
# 7         1.020833
# 12        1.025000
# 13        1.178571
# 27        1.119048
# 44        1.031250
# 47        1.360000
# 52        1.064516
# 59        1.175439
# 60        1.242424
# 66        1.133333
# 68        1.363636
# 75        1.100000
# 76        1.395522
# 97        1.107143
# 98        1.057143
# 101       1.020408
# 106       1.371429
# 108       1.714286
# 109       1.156250
# 111       1.105263
# 116       1.050000
# 117       1.064516
# 118       1.285714
# 119       1.037736
# ...            ...
# 2330      1.352941
# 2335      1.250000
# 2337      1.625000
# 2351      1.437500
# 2356      2.066667
# 2363      1.034483
# 2367      1.037037
# 2376      1.227273
# 2377      1.157895
# 2384      1.160000
# 2392      1.444444
# 2401      1.200000
# 2413      1.222222
# 2440      1.287879
# 2444      1.034483
# 2634      1.068966
# 2716      1.111111
# 2717      1.164384
# 2723      1.357333
# 2728      1.450980
# 2750      1.040000
# 2791      1.125000
# 2817      1.148148
# 2821      1.291667
# 2825      1.363636
#
# [450 rows x 21 columns]

# %% [markdown]
# *** Graphs ***

# %%
#wb.groupby('user_screen_name').favorite_count.mean()

# %%
#wb.groupby('user_screen_name').retweet_count.median()

# %%
wb.head()
# Out:
#    index                  id user_screen_name          created_at  favorite_count  retweet_count  \
# 0  29963  699066909552201728        WorldBank 2016-02-15 03:05:13              34             60
# 1  29964  699036717169451009        WorldBank 2016-02-15 01:05:15              60             70
# 2  29965  699006510848995333        WorldBank 2016-02-14 23:05:13              50             68
# 3  29966  698976317883154432        WorldBank 2016-02-14 21:05:15              28             45
# 4  29967  698946155825250304        WorldBank 2016-02-14 19:05:23              43             96
#
#                                                 text  length  is_RT has_ht has_link has_at                       tags  \
# 0  75% of world’s coral #reefs are threatened. Th...     139  False   True     True  False                      reefs
# 1  When girls stay an extra yr in secondary schoo...     136  False  False     True  False
# 2  Among the poor, 78% live in rural areas, &amp;...     140  False   True     True  False                 Endpoverty
# 3  #Pakistan leads south #Asia in #mobilemoney. T...     105  False   True     True  False  Pakistan Asia mobilemoney
# 4  Constraints such as lack of bank accounts make...     138  False   True     True  False                    poverty
#
#   users                                         text_clean  has_retweet  has_favorite year year_cat year_month
# 0         of worldcoral  reefs are threatened  Their su...            1             1   16       16      16-02
# 1        When girls stay an extra yr in secondary schoo...            1             1   16       16      16-02
# 2        Among the poor   live in rural areas     500M ...            1             1   16       16      16-02
# 3         Pakistan leads south  Asia in  mobilemoney  T...            1             1   16       16      16-02
# 4        Constraints such as lack of bank accounts make...            1             1   16       16      16-02

# %%
wb.retweet_count.describe()
# Out:
# count    2830.000000
# mean       58.586926
# std        48.550601
# min         0.000000
# 25%        32.000000
# 50%        47.000000
# 75%        70.000000
# max      1087.000000
# Name: retweet_count, dtype: float64

# %%
sns.set(style="darkgrid", color_codes=True)
sns.set_context("paper")
plt.figure(figsize=(16, 8))
sns.boxplot(x="year_month",y="retweet_count",data=wb)
sns.plt.title("World Bank Account Retweet Counts")
plt.show()

# %%
sns.set(style="darkgrid", color_codes=True)
sns.set_context("paper")
plt.figure(figsize=(16, 8))
sns.boxplot(x="user_screen_name",y="favorite_count",data=wb)
plt.show()

# %% [markdown]
# **Plot favorite counts by year, and colored by user**

# %%
'''
sns.set(style="darkgrid", color_codes=True)
sns.set_context("paper")
plt.figure(figsize=(12, 8))
test1 = sns.stripplot(x="year_cat",y="favorite_count",data=wb, hue="user_screen_name",jitter=True)
#Q: How to save sns plots
#Q: How to show all the labels in the legend
#test1.savefig('./data/favorite_year.png')
'''
# Out:
# '\nsns.set(style="darkgrid", color_codes=True)\nsns.set_context("paper")\nplt.figure(figsize=(12, 8))\ntest1 = sns.stripplot(x="year_cat",y="favorite_count",data=wb, hue="user_screen_name",jitter=True)\n#Q: How to save sns plots\n#Q: How to show all the labels in the legend\n#test1.savefig(\'./data/favorite_year.png\')\n'

# %% [markdown]
# **Plot retweet counts by year, and colored by user**

# %%
sns.set(style="darkgrid", color_codes=True)
sns.set_context("paper")
plt.figure(figsize=(12, 8))
sns.stripplot(x="year_month",y="retweet_count", data=wb,jitter=True)
#sns.stripplot(x="year_cat",y="retweet_count",hue="user_screen_name", data=wb,jitter=True)
plt.show()

# %% [markdown]
# ### How does tweeting behavior differ between accounts

# %% [markdown]
# **What are the most common users, tags, and words in the top retweet, favorite and zero retweet/favorite**
#
# Popular users:
#
# rkyte365: Special Representative of the UN Secretary General for Sustainable Energy and CEO SE4ALL
#
# diop_wb:
#
# misswakoli: Young,Gifted and Black~Winner of @WorldBankKenya 2015 blog contest~Mentor @AkiliDada~Engineer in Energy Sector~African Woman

# %%
#Summarize USERS, WORDS, and TAGS in tweets
def topusers(dat):
    # create a document-term matrix using TF-IDF
    vect = CountVectorizer()
    dtm = vect.fit_transform(dat.users)
    features = vect.get_feature_names()
    counts = np.sum(dtm.toarray(), axis=0)
    # create a DataFrame of tokens with their counts
    print pd.DataFrame({'token':features, 'count':counts}).sort_values('count', ascending=False).head(10)

def topwords(dat):
    # create a document-term matrix using TF-IDF
    vect = CountVectorizer(stop_words='english')
    dtm = vect.fit_transform(dat.text_clean)
    features = vect.get_feature_names()
    counts = np.sum(dtm.toarray(), axis=0)
    # create a DataFrame of tokens with their counts
    print pd.DataFrame({'token':features, 'count':counts}).sort_values('count', ascending=False).head(10)

def toptags(dat):
    # create a document-term matrix using TF-IDF
    vect = CountVectorizer()
    dtm = vect.fit_transform(dat.tags)
    features = vect.get_feature_names()
    counts = np.sum(dtm.toarray(), axis=0)
    # create a DataFrame of tokens with their counts
    print pd.DataFrame({'token':features, 'count':counts}).sort_values('count', ascending=False).head(10)

# %%
wb.shape
# Out:
# (2830, 20)

# %%
#Examine the top users, words, and tags in the data
topusers(wb)
topwords(wb)
toptags(wb)
# Out:
#      count            token
# 85     280       jimkim_wbg
# 191    115        worldbank
# 36      22  connect4climate
# 110     19          mzveegh
# 109     18     musicnegrito
# 195     18    worldbanklive
# 43      16      drewholcomb
# 42      16       djokernole
# 77      15          ifc_org
# 89      13     kaushikcbasu
#       count          token
# 4453    310            wbg
# 3244    258        poverty
# 974     184      countries
# 4537    164          women
# 1419    158     endpoverty
# 3252    152            ppl
# 800     148  climatechange
# 2029    147           help
# 2604    140           live
# 4573    134          world
#      count          token
# 197    158     endpoverty
# 96     147  climatechange
# 112    134          cop21
# 494    123        poverty
# 11     108         africa
# 290     67        goodgov
# 424     66      music4dev
# 174     59      education
# 94      51        climate
# 281     51    globalgoals

# %%
wb1=wb[(wb.retweet_count>70)]
wb1.shape
# Out:
# (704, 20)

# %%
topusers(wb1)
topwords(wb1)
toptags(wb1)
# Out:
#     count          token
# 11     61     jimkim_wbg
# 33     13      worldbank
# 6       6     djokernole
# 25      5       un_women
# 35      5  worldbanklive
# 23      4         thegef
# 17      4        mzveegh
# 29      2     wbg_cities
# 8       2           icrw
# 10      2        ifc_org
#       count          token
# 1263    111        poverty
# 1735     66          women
# 1269     65            ppl
# 378      63      countries
# 1709     63            wbg
# 554      56     endpoverty
# 69       51         access
# 309      48  climatechange
# 366      47            cop
# 93       44         africa
#      count          token
# 85      56     endpoverty
# 50      52          cop21
# 191     49        poverty
# 40      48  climatechange
# 4       40         africa
# 38      19        climate
# 51      17     corruption
# 142     17          india
# 254     16        wdr2016
# 57      16           data

# %%
wb1=wb[(wb.favorite_count>49)]
wb1.shape
# Out:
# (699, 20)

# %%
topusers(wb1)
topwords(wb1)
toptags(wb1)
# Out:
#     count          token
# 13     69     jimkim_wbg
# 6       7     djokernole
# 21      6        mzveegh
# 39      6      worldbank
# 30      4         thegef
# 31      4       un_women
# 42      4  worldbanklive
# 17      4     malalafund
# 4       3           cgap
# 14      2  justintrudeau
#       count          token
# 1267    102        poverty
# 1724     73            wbg
# 555      57     endpoverty
# 1755     55          women
# 382      55      countries
# 368      52            cop
# 68       50         access
# 1273     46            ppl
# 311      41  climatechange
# 791      41           help
#      count          token
# 51      59          cop21
# 87      57     endpoverty
# 199     47        poverty
# 44      41  climatechange
# 5       34         africa
# 78      24      education
# 264     20        wdr2016
# 12      18    agriculture
# 146     16     inequality
# 42      16        climate

# %%
wb4=wb[(wb.user_screen_name!="WorldBank") &(wb.user_screen_name!="JimKim_WBG")]
wb5=wb[(wb.user_screen_name!="WorldBank") &(wb.user_screen_name!="JimKim_WBG") & (wb.retweet_count>10)]

# %%
topusers(wb4)
topwords(wb4)
toptags(wb4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-206-9e48e81f59db> in <module>()
# ----> 1 topusers(wb4)
#       2 topwords(wb4)
#       3 toptags(wb4)
#
# <ipython-input-198-0a4c0ef9d683> in topusers(dat)
#       3     # create a document-term matrix using TF-IDF
#       4     vect = CountVectorizer()
# ----> 5     dtm = vect.fit_transform(dat.users)
#       6     features = vect.get_feature_names()
#       7     counts = np.sum(dtm.toarray(), axis=0)
#
# /Users/judyyang/anaconda/lib/python2.7/site-packages/sklearn/feature_extraction/text.pyc in fit_transform(self, raw_documents, y)
#     802
#     803         vocabulary, X = self._count_vocab(raw_documents,
# --> 804                                           self.fixed_vocabulary_)
#     805
#     806         if self.binary:
#
# /Users/judyyang/anaconda/lib/python2.7/site-packages/sklearn/feature_extraction/text.pyc in _count_vocab(self, raw_documents, fixed_vocab)
#     749             vocabulary = dict(vocabulary)
#     750             if not vocabulary:
# --> 751                 raise ValueError("empty vocabulary; perhaps the documents only"
#     752                                  " contain stop words")
#     753
#
# ValueError: empty vocabulary; perhaps the documents only contain stop words
